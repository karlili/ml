# %% [markdown]
# [View in Colaboratory](https://colab.research.google.com/github/karlili/ml/blob/master/Plotting_&_Pandas_101.ipynb)

# %%
#Putting all the imports
import numpy as np
import matplotlib.pyplot as plt

import pandas

# %%
# Fixing random state for reproducibility
np.random.seed(19680801)


N = 2000
x = np.random.rand(N)
y = np.random.rand(N)
colors = np.random.rand(N)
area = (30 * np.random.rand(N))**2  # 0 to 15 point radii

plt.scatter(x, y, s=area, c=colors, alpha=0.5)
plt.show()

# %%
#tabulation of data
data = [[ 66386, 174296,  75131, 577908,  32015],
        [ 58230, 381139,  78045,  99308, 160454],
        [ 89135,  80552, 152558, 497981, 603535],
        [ 78415,  81858, 150656, 193263,  69638],
        [139361, 331509, 343164, 781380,  52269]]

pandas.DataFrame(data)
# Out:
#         0       1       2       3       4
# 0   66386  174296   75131  577908   32015
# 1   58230  381139   78045   99308  160454
# 2   89135   80552  152558  497981  603535
# 3   78415   81858  150656  193263   69638
# 4  139361  331509  343164  781380   52269

# %%
#Getting a single column from the data
#1. converting to np array
np_data_array = np.array(data)
first_col_data = np_data_array[:,0]
pandas.DataFrame(first_col_data)
# Out:
#         0
# 0   66386
# 1   58230
# 2   89135
# 3   78415
# 4  139361
